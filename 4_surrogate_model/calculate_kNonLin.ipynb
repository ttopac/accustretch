# %%
import pandas as pd

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
import pickle
from pickle import dump

import matplotlib.pyplot as plt

# %%
#Re-create the CSV files containing experiment data (8leg)
# import utils
# filename = "8legs_new300LH_NT2_RF1.csv"
# legList = [8]
# utils.createSamplesCSVfromGsheets(legList, filename, k0type="simulated")

# %%
#Re-create the CSV files containing experiment data (68leg)
# import utils
# filename = "68legs_NT2_RF1.csv"
# leg = 68
# utils.createSamplesCSVfromGsheets(leg, filename, k0type="simulated", multiLeg=True)

# %%
#Re-create the CSV files containing experiment data (246810leg)
# import utils
# filename = "246810legs_NT2_RF1_wlegs.csv"
# leg = 246810
# utils.createSamplesCSVfromGsheets(leg, filename, k0type="simulated", multiLeg=True)

# %%
#Re-create the CSV files containing experiment data (246leg)
# import utils
# filename = "246legs_NT2_RF1_wlegs_v4.csv"
# leg = 246
# utils.createSamplesCSVfromGsheets(leg, filename, k0type="simulated", multiLeg=True)

# %%
dataframe = pd.read_csv("246legs_NT2_RF1_wlegs_v4.csv", header=None) #Last 10 columns are f1, f2, ..., f10 outputs
num_cols = len(dataframe.columns)

#Shuffling
dataframe = dataframe.sample(frac = 1)
dataset = dataframe.values

#Scaling
inp_scaler = StandardScaler()
out_scaler = StandardScaler()
# inp_scaler.fit(dataset[:,0:num_cols-10]) #w legs
# out_scaler.fit(dataset[:,num_cols-10:]) #w legs
inp_scaler.fit(dataset[:,0:2]) #wo legs
out_scaler.fit(dataset[:,3:]) #wo legs
# scaled_inputs = inp_scaler.transform(dataset[:,0:num_cols-10]) #w legs
# scaled_outputs = out_scaler.transform(dataset[:,num_cols-10:]) #w legs
scaled_inputs = inp_scaler.transform(dataset[:,0:2]) #wo legs
scaled_outputs = out_scaler.transform(dataset[:,3:]) #wo legs

dump(inp_scaler, open('inp_scaler246_v4_wolegs.pkl', 'wb'))
dump(out_scaler, open('out_scaler246_v4_wolegs.pkl', 'wb'))

# %%
num_exps = dataset.shape[0]
train_exps = round(num_exps*0.90)

#Scaling
X_train = scaled_inputs[0:train_exps] #k0, dmax
Y_train = scaled_outputs[0:train_exps] #f01, f02, ..., f10
X_test = scaled_inputs[train_exps:]
Y_test = scaled_outputs[train_exps:]

# %%
#Define Keras regression model
def regression_model():
    model = Sequential()
    model.add(Dense(12, input_dim=2, kernel_initializer='normal', activation='relu'))
    model.add(Dense(5, kernel_initializer='normal', activation='relu'))
    model.add(Dense(10, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Train the estimator
estimator = regression_model()
hist = estimator.fit(X_train, Y_train, epochs=2000, batch_size=20, verbose=1, shuffle=False, validation_data=(X_test,Y_test))
# Out:
#  val_loss: 0.0022
# Epoch 1816/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1817/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1818/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1819/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1820/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1821/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1822/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1823/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1824/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1825/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1826/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1827/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1828/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0024 - val_loss: 0.0022
# Epoch 1829/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1830/2000
# 810/810 [==============================] - 0s 90us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1831/2000
# 810/810 [==============================] - 0s 75us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1832/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1833/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1834/2000
# 810/810 [==============================] - 0s 86us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1835/2000
# 810/810 [==============================] - 0s 84us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1836/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1837/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1838/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1839/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1840/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1841/2000
# 810/810 [==============================] - 0s 84us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1842/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1843/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1844/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1845/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1846/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1847/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1848/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1849/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1850/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1851/2000
# 810/810 [==============================] - 0s 88us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1852/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1853/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1854/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1855/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1856/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1857/2000
# 810/810 [==============================] - 0s 84us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1858/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1859/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1860/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1861/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1862/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1863/2000
# 810/810 [==============================] - 0s 85us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1864/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1865/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1866/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1867/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1868/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1869/2000
# 810/810 [==============================] - 0s 84us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1870/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1871/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1872/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1873/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1874/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1875/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1876/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1877/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1878/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1879/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1880/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1881/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1882/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1883/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1884/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1885/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1886/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1887/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1888/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1889/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1890/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1891/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1892/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1893/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1894/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1895/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1896/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1897/2000
# 810/810 [==============================] - 0s 93us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1898/2000
# 810/810 [==============================] - 0s 75us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1899/2000
# 810/810 [==============================] - 0s 102us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1900/2000
# 810/810 [==============================] - 0s 93us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1901/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1902/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1903/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1904/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1905/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1906/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1907/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1908/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1909/2000
# 810/810 [==============================] - 0s 88us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1910/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1911/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1912/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1913/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1914/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1915/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1916/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1917/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1918/2000
# 810/810 [==============================] - 0s 84us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1919/2000
# 810/810 [==============================] - 0s 75us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1920/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1921/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1922/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1923/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1924/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1925/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1926/2000
# 810/810 [==============================] - 0s 75us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1927/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1928/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1929/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1930/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1931/2000
# 810/810 [==============================] - 0s 104us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1932/2000
# 810/810 [==============================] - 0s 75us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1933/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1934/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1935/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1936/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1937/2000
# 810/810 [==============================] - 0s 86us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1938/2000
# 810/810 [==============================] - 0s 74us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1939/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1940/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1941/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1942/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1943/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1944/2000
# 810/810 [==============================] - 0s 84us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1945/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1946/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1947/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1948/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1949/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1950/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1951/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1952/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1953/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1954/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1955/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1956/2000
# 810/810 [==============================] - 0s 76us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1957/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1958/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1959/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1960/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1961/2000
# 810/810 [==============================] - 0s 85us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1962/2000
# 810/810 [==============================] - 0s 74us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1963/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1964/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1965/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1966/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1967/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1968/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1969/2000
# 810/810 [==============================] - 0s 86us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1970/2000
# 810/810 [==============================] - 0s 86us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1971/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1972/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1973/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1974/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1975/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1976/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1977/2000
# 810/810 [==============================] - 0s 84us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1978/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1979/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1980/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1981/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1982/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1983/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1984/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1985/2000
# 810/810 [==============================] - 0s 86us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1986/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1987/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1988/2000
# 810/810 [==============================] - 0s 77us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1989/2000
# 810/810 [==============================] - 0s 80us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1990/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1991/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1992/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1993/2000
# 810/810 [==============================] - 0s 84us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1994/2000
# 810/810 [==============================] - 0s 74us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1995/2000
# 810/810 [==============================] - 0s 78us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1996/2000
# 810/810 [==============================] - 0s 82us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1997/2000
# 810/810 [==============================] - 0s 81us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1998/2000
# 810/810 [==============================] - 0s 83us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 1999/2000
# 810/810 [==============================] - 0s 79us/sample - loss: 0.0023 - val_loss: 0.0022
# Epoch 2000/2000
# 810/810 [==============================] - 0s 85us/sample - loss: 0.0023 - val_loss: 0.0022

# %%
estimator.save("246leg_v4_NN_model_NT2_random_RF1_scaled_wolegs.h5") #UNCOMMENT ONLY IF WE MADE NECESSARY CHANGES

# %%
# Get train params
print ("Training loss: {}".format(hist.history['loss'][-1]))
print ("Test loss: {}".format(hist.history['val_loss'][-1]))
plt.ylim(0,1e-1)
plt.plot (hist.history['loss'])
plt.plot (hist.history['val_loss'])
plt.legend(["train_loss","val_loss"])
# Out:
# Training loss: 0.002323487135409205
# Test loss: 0.002179199286426107

# %%
# estimator = keras.models.load_model("8leg_NN_model_NT2_300LH_scaled.h5")
test_sample = np.asarray([1.96E-4, 23.26]).reshape(1,2)

#Scaling
test_sample_scaled = inp_scaler.transform(test_sample)
scaled_nonlin_force = estimator.predict (test_sample_scaled)
nonlin_force = out_scaler.inverse_transform(scaled_nonlin_force)

print (nonlin_force)
# Out:
# [[0.00026149 0.00052593 0.00080858 0.00113506 0.00148779 0.00194422
#   0.002502   0.00334487 0.00434916 0.00536852]]

# %%
#Scaling
displacement_train = np.linspace(0,dataset[0:train_exps,1],10).T
scaled_prediction_train = estimator.predict(X_train[0:3,:])
prediction_train = out_scaler.inverse_transform(scaled_prediction_train)
displacement_test = np.linspace(0,dataset[train_exps:,1],10).T
scaled_prediction_test = estimator.predict(X_test[0:3,:])
prediction_test = out_scaler.inverse_transform(scaled_prediction_test)

#Run:
for i in range(3):
    fig = plt.figure(figsize = (10,4))
    axs = plt.subplot(121)
    axs.plot(displacement_train[i], dataset[i,2:], '-o', displacement_train[i], prediction_train[i], '-o')
    axs.set(xlabel="Displacement (mm)", ylabel="Force",
            title="F-d plot for sample {} on training data".format(i))
    axs.legend(["real data","prediction"])
    axs = plt.subplot(122)
    axs.plot(displacement_test[i], dataset[i+train_exps,2:], '-o', displacement_test[i], prediction_test[i], '-o')
    axs.set(xlabel="Displacement (mm)", ylabel="Force", title="F-d plot for sample {} on test data".format(i))
    axs.legend(["real data","prediction"])
